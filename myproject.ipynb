# %% [markdown]
# <a href="https://colab.research.google.com/github/seo03/DL23_Project_G2/blob/main/myproject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #⭐**The Perfect Match**

# %% [markdown]
# hello!

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# Getting text from the user
user_text = input("Please paste your text here: ")


wordcloud = WordCloud(
    background_color='white',
    width=800,
    height=800,
    max_words=100
).generate(user_text)

plt.figure(figsize=(8, 8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
# Out:
# Please paste your text here: The Perfect Match" portrays a future society dominated by a giant corporation's AI creation, Tilly. The protagonist, Sai, lives a life dictated by Tilly's instructions but begins to feel a sense of disillusionment. He meets Jenny, a woman living next door who rejects not only Tilly but also other aspects of the IT civilization. They have many conversations and gradually spend more time together, falling in love.  However, their plan to get rid of Tilly is discovered by Centillion, the company behind Tilly, and both Sai and Jenny are offered job positions by Centillion's people who aim to further enhance Tilly's flaws. The novel concludes by showcasing the conversations between Sai and Tilly.

# %% [markdown]
# plot
#
#
#
# The Perfect Match" portrays a future society dominated by a giant corporation's AI creation, Tilly. The protagonist, Sai, lives a life dictated by Tilly's instructions but begins to feel a sense of disillusionment. He meets Jenny, a woman living next door who rejects not only Tilly but also other aspects of the IT civilization. They have many conversations and gradually spend more time together, falling in love.
#
# However, their plan to get rid of Tilly is discovered by Centillion, the company behind Tilly, and both Sai and Jenny are offered job positions by Centillion's people who aim to further enhance Tilly's flaws. The novel concludes by showcasing the conversations between Sai and Tilly.

# %% [markdown]
# 단어퀴즈 - 코딩
#
# recommend, refuse, install, seperate, figure out, monitor, observe, promote, illegal, neglect

# %% [markdown]
# 줄거리 문제 - 구글

# %% [markdown]
# 토론주제
# 1. If Personal Artificial Intelligence (P.A.I) systems like Tilly from 'The Perfect Match' were invented in the future, what are your thoughts on the potential benefits and drawbacks of using such companions? Would you be willing to use one?
# 2. Considering the emotional connection and bond portrayed between Sai and his personal artificial intelligene (P.A.I) companion, Tilly, in 'The Perfect Match', do you think it is possible for humans to form deep relationships with P.A.I. systems?
